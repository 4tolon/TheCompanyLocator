# %% [markdown]
# # Empresas Tech de Madrid

# %%
from pymongo import MongoClient
import pandas as pd
import requests
import sys
import func as fc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1700/1147851701.py in <module>
#       3 import requests
#       4 import sys
# ----> 5 import func as fc
#
# ModuleNotFoundError: No module named 'func'

# %% [markdown]
# Generamos la conexsion con la base de datos

# %%
client = MongoClient("localhost:27017")
db = client.get_database("ironhack")
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack')

# %%
db.list_collection_names()
# Out:
# ['companies']

# %%
c = db.get_collection("companies")

# %%
c
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack'), 'companies')

# %%
listaempresas = list(db["companies"].find({},{"_id":0,"name":1,"offices":1}))

# %%
df_emp = pd.DataFrame(listaempresas)

# %%
df_emp
# Out:
#                       name                                            offices
# 0                 Wetpaint  [{'description': '', 'address1': '710 - 2nd Av...
# 1                AdventNet  [{'description': 'Headquarters', 'address1': '...
# 2                     Zoho  [{'description': 'Headquarters', 'address1': '...
# 3                     Digg  [{'description': None, 'address1': '135 Missis...
# 4                 Facebook  [{'description': 'Headquarters', 'address1': '...
# ...                    ...                                                ...
# 18796               Adhunk  [{'description': 'Indian Office', 'address1': ...
# 18797           AfterLogic  [{'description': 'Livingston', 'address1': 'P....
# 18798          goBookmaker                                                 []
# 18799  EnteGreat Solutions  [{'description': '', 'address1': '', 'address2...
# 18800            EnteGreat  [{'description': '', 'address1': '1900 Interna...
#
# [18801 rows x 2 columns]

# %%
df_emp = df_emp.explode('offices')

# %%
df_emp
# Out:
#                       name                                            offices
# 0                 Wetpaint  {'description': '', 'address1': '710 - 2nd Ave...
# 0                 Wetpaint  {'description': '', 'address1': '270 Lafayette...
# 1                AdventNet  {'description': 'Headquarters', 'address1': '4...
# 2                     Zoho  {'description': 'Headquarters', 'address1': '4...
# 3                     Digg  {'description': None, 'address1': '135 Mississ...
# ...                    ...                                                ...
# 18796               Adhunk  {'description': 'Indian Office', 'address1': '...
# 18797           AfterLogic  {'description': 'Livingston', 'address1': 'P.O...
# 18798          goBookmaker                                                NaN
# 18799  EnteGreat Solutions  {'description': '', 'address1': '', 'address2'...
# 18800            EnteGreat  {'description': '', 'address1': '1900 Internat...
#
# [21762 rows x 2 columns]

# %%
df_ofis = df_emp[["offices"]].apply(lambda x: x.offices, result_type="expand", axis=1)

# %%
df_ofis
# Out:
#          description                       address1     address2    zip_code  \
# 0                                  710 - 2nd Avenue   Suite 1100       98104
# 0                              270 Lafayette Street    Suite 505       10012
# 1       Headquarters               4900 Hopyard Rd.    Suite 310       94588
# 2       Headquarters                4900 Hopyard Rd    Suite 310       94588
# 3               None             135 Mississippi St                    94107
# ...              ...                            ...          ...         ...
# 18796  Indian Office          Near Tube Well(south)  Patel Nagar      334003
# 18797     Livingston                  P.O. Box 2096                    07039
# 18798            NaN                            NaN          NaN         NaN
# 18799
# 18800                 1900 International Park Drive    Suite 200  35243-4204
#
#                 city state_code country_code   latitude   longitude
# 0            Seattle         WA          USA  47.603122 -122.333253
# 0           New York         NY          USA  40.723731  -73.996431
# 1         Pleasanton         CA          USA  37.692934 -121.904945
# 2         Pleasanton         CA          USA  37.692934 -121.904945
# 3      San Francisco         CA          USA  37.764726 -122.394523
# ...              ...        ...          ...        ...         ...
# 18796        Bikaner       None          IND        NaN         NaN
# 18797     Livingston         NJ          USA  40.793024  -74.323554
# 18798            NaN        NaN          NaN        NaN         NaN
# 18799     Birmingham         AL          USA  33.518885  -86.816068
# 18800     Birmingham         AL          USA  33.407786  -86.761302
#
# [21762 rows x 9 columns]

# %%
df_mad = df_ofis[df_ofis['city'] == 'Madrid']

# %%
df_mad
# Out:
#            description                       address1  \
# 48       Google Madrid                  Torre Picasso
# 232          Tru Spain         Gran Via, 6. 4th floor
# 673                            Calle Quintanavides 15
# 2036             Spain     Calle Javier Ferrero 13-15
# 2195              None
# ...                ...                            ...
# 18010                   C/ Fortuny, 45 bajo izquierda
# 18010                                 Rafael Calvo 42
# 18094            Spain                   c/marathon 6
# 18230  affilinet Spain           affilinet Espana SLU
# 18255           Office  33. Edificio Atica 4 planta 2
#
#                           address2 zip_code    city state_code country_code  \
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# 232                                   28013  Madrid       None          ESP
# 673                            2-1    28050  Madrid       None          ESP
# 2036                                  28002  Madrid       None          ESP
# 2195                                         Madrid       None          ESP
# ...                            ...      ...     ...        ...          ...
# 18010                                 28010  Madrid       None          ESP
# 18010                   Under Dcha    28010  Madrid       None          ESP
# 18094                     planta 1    28037  Madrid       None          ESP
# 18230  VelÃ¡zquez 12, 7a-8a planta    28001  Madrid       None          ESP
# 18255    28224 Pozuelo de AlarcÃ³n           Madrid       None          ESP
#
#         latitude  longitude
# 48           NaN        NaN
# 232          NaN        NaN
# 673    40.530724  -3.632687
# 2036   40.448797  -3.669764
# 2195   40.416741  -3.703250
# ...          ...        ...
# 18010        NaN        NaN
# 18010        NaN        NaN
# 18094        NaN        NaN
# 18230        NaN        NaN
# 18255  40.416741  -3.703250
#
# [86 rows x 9 columns]

# %%
df_mad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 48 to 18255
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   description   82 non-null     object
#  1   address1      86 non-null     object
#  2   address2      86 non-null     object
#  3   zip_code      86 non-null     object
#  4   city          86 non-null     object
#  5   state_code    1 non-null      object
#  6   country_code  86 non-null     object
#  7   latitude      53 non-null     float64
#  8   longitude     53 non-null     float64
# dtypes: float64(2), object(7)
# memory usage: 6.7+ KB

# %%
df_madrid = df_emp.merge(df_mad, how='inner', left_index=True, right_index=True)

# %%
df_madrid
# Out:
#                name                                            offices  \
# 48           Google  {'description': 'Google Headquarters', 'addres...
# 48           Google  {'description': 'Google Ann Arbor', 'address1'...
# 48           Google  {'description': 'Google Atlanta', 'address1': ...
# 48           Google  {'description': 'Google Austin', 'address1': '...
# 48           Google  {'description': 'Google Boulder', 'address1': ...
# ...             ...                                                ...
# 18230  AdLINK Group  {'description': 'affilnet Netherlands', 'addre...
# 18230  AdLINK Group  {'description': 'affilinet Spain', 'address1':...
# 18230  AdLINK Group  {'description': 'affilinet UK', 'address1': 'a...
# 18230  AdLINK Group  {'description': 'Sedo USA', 'address1': 'Sedo....
# 18255        BuyVIP  {'description': 'Office', 'address1': '33. Edi...
#
#            description                       address1  \
# 48       Google Madrid                  Torre Picasso
# 48       Google Madrid                  Torre Picasso
# 48       Google Madrid                  Torre Picasso
# 48       Google Madrid                  Torre Picasso
# 48       Google Madrid                  Torre Picasso
# ...                ...                            ...
# 18230  affilinet Spain           affilinet Espana SLU
# 18230  affilinet Spain           affilinet Espana SLU
# 18230  affilinet Spain           affilinet Espana SLU
# 18230  affilinet Spain           affilinet Espana SLU
# 18255           Office  33. Edificio Atica 4 planta 2
#
#                           address2 zip_code    city state_code country_code  \
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# ...                            ...      ...     ...        ...          ...
# 18230  VelÃ¡zquez 12, 7a-8a planta    28001  Madrid       None          ESP
# 18230  VelÃ¡zquez 12, 7a-8a planta    28001  Madrid       None          ESP
# 18230  VelÃ¡zquez 12, 7a-8a planta    28001  Madrid       None          ESP
# 18230  VelÃ¡zquez 12, 7a-8a planta    28001  Madrid       None          ESP
# 18255    28224 Pozuelo de AlarcÃ³n           Madrid       None          ESP
#
#         latitude  longitude
# 48           NaN        NaN
# 48           NaN        NaN
# 48           NaN        NaN
# 48           NaN        NaN
# 48           NaN        NaN
# ...          ...        ...
# 18230        NaN        NaN
# 18230        NaN        NaN
# 18230        NaN        NaN
# 18230        NaN        NaN
# 18255  40.416741   -3.70325
#
# [324 rows x 11 columns]

# %%
df_madrid = df_emp.merge(df_mad, how='inner', left_index=True, right_index = True)
df_madrid
# Out:
#                name                                            offices  \
# 48           Google  {'description': 'Google Headquarters', 'addres...
# 48           Google  {'description': 'Google Ann Arbor', 'address1'...
# 48           Google  {'description': 'Google Atlanta', 'address1': ...
# 48           Google  {'description': 'Google Austin', 'address1': '...
# 48           Google  {'description': 'Google Boulder', 'address1': ...
# ...             ...                                                ...
# 18230  AdLINK Group  {'description': 'affilnet Netherlands', 'addre...
# 18230  AdLINK Group  {'description': 'affilinet Spain', 'address1':...
# 18230  AdLINK Group  {'description': 'affilinet UK', 'address1': 'a...
# 18230  AdLINK Group  {'description': 'Sedo USA', 'address1': 'Sedo....
# 18255        BuyVIP  {'description': 'Office', 'address1': '33. Edi...
#
#            description                       address1  \
# 48       Google Madrid                  Torre Picasso
# 48       Google Madrid                  Torre Picasso
# 48       Google Madrid                  Torre Picasso
# 48       Google Madrid                  Torre Picasso
# 48       Google Madrid                  Torre Picasso
# ...                ...                            ...
# 18230  affilinet Spain           affilinet Espana SLU
# 18230  affilinet Spain           affilinet Espana SLU
# 18230  affilinet Spain           affilinet Espana SLU
# 18230  affilinet Spain           affilinet Espana SLU
# 18255           Office  33. Edificio Atica 4 planta 2
#
#                           address2 zip_code    city state_code country_code  \
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# ...                            ...      ...     ...        ...          ...
# 18230  VelÃ¡zquez 12, 7a-8a planta    28001  Madrid       None          ESP
# 18230  VelÃ¡zquez 12, 7a-8a planta    28001  Madrid       None          ESP
# 18230  VelÃ¡zquez 12, 7a-8a planta    28001  Madrid       None          ESP
# 18230  VelÃ¡zquez 12, 7a-8a planta    28001  Madrid       None          ESP
# 18255    28224 Pozuelo de AlarcÃ³n           Madrid       None          ESP
#
#         latitude  longitude
# 48           NaN        NaN
# 48           NaN        NaN
# 48           NaN        NaN
# 48           NaN        NaN
# 48           NaN        NaN
# ...          ...        ...
# 18230        NaN        NaN
# 18230        NaN        NaN
# 18230        NaN        NaN
# 18230        NaN        NaN
# 18255  40.416741   -3.70325
#
# [324 rows x 11 columns]

# %%
df_madrid.drop_duplicates(subset='name', 
                          keep='first', 
                          inplace=True, 
                          ignore_index=False)
df_madrid
# Out:
#                name                                            offices  \
# 48           Google  {'description': 'Google Headquarters', 'addres...
# 232        Truphone  {'description': 'Tru UK / Head Office', 'addre...
# 673             Fon  {'description': '', 'address1': 'Calle Quintan...
# 2036     Buongiorno  {'description': '', 'address1': 'Via Cosimo de...
# 2195         Swotti  {'description': None, 'address1': '', 'address...
# ...             ...                                                ...
# 17804       Genasys  {'description': '', 'address1': 'C/ Ventura de...
# 18010           FRV  {'description': '', 'address1': 'C/ Fortuny, 4...
# 18094      StreamUK  {'description': 'HQ', 'address1': '1 Water Lan...
# 18230  AdLINK Group  {'description': 'AdLINK Internet Media AG', 'a...
# 18255        BuyVIP  {'description': 'Office', 'address1': '33. Edi...
#
#            description                       address1  \
# 48       Google Madrid                  Torre Picasso
# 232          Tru Spain         Gran Via, 6. 4th floor
# 673                            Calle Quintanavides 15
# 2036             Spain     Calle Javier Ferrero 13-15
# 2195              None
# ...                ...                            ...
# 17804                         C/ Ventura de la Vega 5
# 18010                   C/ Fortuny, 45 bajo izquierda
# 18094            Spain                   c/marathon 6
# 18230  affilinet Spain           affilinet Espana SLU
# 18255           Office  33. Edificio Atica 4 planta 2
#
#                           address2 zip_code    city state_code country_code  \
# 48      Plaza Pablo Ruiz Picasso 1    28020  Madrid       None          ESP
# 232                                   28013  Madrid       None          ESP
# 673                            2-1    28050  Madrid       None          ESP
# 2036                                  28002  Madrid       None          ESP
# 2195                                         Madrid       None          ESP
# ...                            ...      ...     ...        ...          ...
# 17804                 28014 Madrid           Madrid       None          ESP
# 18010                                 28010  Madrid       None          ESP
# 18094                     planta 1    28037  Madrid       None          ESP
# 18230  VelÃ¡zquez 12, 7a-8a planta    28001  Madrid       None          ESP
# 18255    28224 Pozuelo de AlarcÃ³n           Madrid       None          ESP
#
#         latitude  longitude
# 48           NaN        NaN
# 232          NaN        NaN
# 673    40.530724  -3.632687
# 2036   40.448797  -3.669764
# 2195   40.416741  -3.703250
# ...          ...        ...
# 17804  40.416184  -3.698873
# 18010        NaN        NaN
# 18094        NaN        NaN
# 18230        NaN        NaN
# 18255  40.416741  -3.703250
#
# [80 rows x 11 columns]

# %%
df_madrid['request'] = df_madrid.address1.apply(fc.geocode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_771/3424662127.py in <module>
# ----> 1 df_madrid['request'] = df_madrid.address1.apply(fc.geocode)
#
# ~/miniconda3/envs/minimal_ds/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/miniconda3/envs/minimal_ds/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/miniconda3/envs/minimal_ds/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~/miniconda3/envs/minimal_ds/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /mnt/c/Users/fzapi/iron/projects/TheCompanyLocator/notebooks/../src/func.py in geocode(adress)
#      12
#      13 def geocode(adress):
# ---> 14     '''
#      15     Funcion para reclamar una direccion en un df mediante geocode.
#      16     Se utiliza con un apply sobre la columna de direciones y el resultado de la funcion se almacena en una nueva clolumna
#
# NameError: name 'requests' is not defined
